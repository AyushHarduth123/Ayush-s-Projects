# %%
import pandas as pd
import numpy as np

import re

import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, Bidirectional

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix

from collections import Counter

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)

# %%
df = pd.read_csv("tweet_emotions.csv")
df.head()
# Out:
#      tweet_id   sentiment  \
# 0  1956967341       empty
# 1  1956967666     sadness
# 2  1956967696     sadness
# 3  1956967789  enthusiasm
# 4  1956968416     neutral
#
#                                                                                         content
# 0  @tiffanylue i know  i was listenin to bad habit earlier and i started freakin at his part =[
# 1                                  Layin n bed with a headache  ughhhh...waitin on your call...
# 2                                                           Funeral ceremony...gloomy friday...
# 3                                                          wants to hang out with friends SOON!
# 4        @dannycastillo We want to trade with someone who has Houston tickets, but no one will.

# %%
df.shape
# Out:
# (40000, 3)

# %%
print(df.columns)
# Out:
# Index(['tweet_id', 'sentiment', 'content'], dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tweet_id   40000 non-null  int64
#  1   sentiment  40000 non-null  str
#  2   content    40000 non-null  str
# dtypes: int64(1), str(2)
# memory usage: 937.6 KB

# %%
df.describe(include = "all")
# Out:
#             tweet_id sentiment  \
# count   4.000000e+04     40000
# unique           NaN        13
# top              NaN   neutral
# freq             NaN      8638
# mean    1.845184e+09       NaN
# std     1.188579e+08       NaN
# min     1.693956e+09       NaN
# 25%     1.751431e+09       NaN
# 50%     1.855443e+09       NaN
# 75%     1.962781e+09       NaN
# max     1.966441e+09       NaN
#
#                                                                                                              content
# count                                                                                                          40000
# unique                                                                                                         39827
# top     I just received a mothers day card from my lovely daughter wishing my a happy mothers day  http://tr.im/kWK9
# freq                                                                                                              14
# mean                                                                                                             NaN
# std                                                                                                              NaN
# min                                                                                                              NaN
# 25%                                                                                                              NaN
# 50%                                                                                                              NaN
# 75%                                                                                                              NaN
# max                                                                                                              NaN

# %%
df.sample(10, random_state = 42)
# Out:
#          tweet_id  sentiment  \
# 32823  1752414968    neutral
# 16298  1965295852      empty
# 28505  1696219218       love
# 6689   1961416554    neutral
# 26893  1695580473    sadness
# 36572  1753331093  happiness
# 12335  1963544918      worry
# 29591  1751287108  happiness
# 18948  1966120040    sadness
# 31067  1751819700     relief
#
#                                                                                                                                           content
# 32823                                                                                                                                Good Morning
# 16298                                    I just put my computer up on craigslist. I've had the same case, monitor, and speakers for over 5 years.
# 28505  in ten minutes shopping   demi lovato-back around demi lovato-behind enemy lines have you all seen the titanic 2 trailer? its really good!
# 6689                                                                       From twitterberry moved to ubertwitter - suffered from BB cache errors
# 26893                                                                                                                           @thriftymom TEAR*
# 36572                                      Ps... I got Ben Button today... completes my Best Picture noms....got all 5 now. It was a GREAT year!!
# 12335                                                 Just fell asleep for 2 &amp; 1/2 hours so missed both chances for first-look Hollyoaks, ugh
# 29591                                                                                           @VanetaRogers Thank ye, Vaneta.  Much appreciated
# 18948                                                                                   @donttreeriddle Oh noes!! Melted ice cream = do not want.
# 31067                                                                                                  @orphanth i just had pasta  from pizzahut.

# %%
number_of_classes = df['sentiment'].nunique()
print(f"Number of sentiment classes: {number_of_classes} ")
# Out:
# Number of sentiment classes: 13

# %%
sentiment_classes = df['sentiment'].unique()
print(sentiment_classes)
# Out:
# <StringArray>
# [     'empty',    'sadness', 'enthusiasm',    'neutral',      'worry',
#    'surprise',       'love',        'fun',       'hate',  'happiness',
#     'boredom',     'relief',      'anger']
# Length: 13, dtype: str

# %%
class_count = df['sentiment'].value_counts()
print(class_count)
# Out:
# sentiment
# neutral       8638
# worry         8459
# happiness     5209
# sadness       5165
# love          3842
# surprise      2187
# fun           1776
# relief        1526
# hate          1323
# empty          827
# enthusiasm     759
# boredom        179
# anger          110
# Name: count, dtype: int64

# %%
plt.figure(figsize = (12,6))
sns.countplot(data = df, y = "sentiment", order = df["sentiment"].value_counts().index)
plt.title("Sentiment Class Distribution")
plt.xlabel("Number of tweets")
plt.ylabel("sentiment")
plt.show()

# %%
print(df.isnull().sum())
# Out:
# tweet_id     0
# sentiment    0
# content      0
# dtype: int64

# %%
duplicate_count = df.duplicated().sum()
print(duplicate_count)
# Out:
# 0

# %%
text_duplicate = df[df["content"].duplicated()]
print(len(text_duplicate))
# Out:
# 173

# %%
print(text_duplicate)
# Out:
#          tweet_id  sentiment                                        content
# 366    1957048870      worry             I feel so deflated. No more doggy.
# 521    1957088574      worry          Somebody please save the polar bears!
# 1026   1957198430    neutral                                    I'm at work
# 3684   1958103183    sadness      @dublins98dave me too! I am down 400 euro
# 4363   1960336689      worry        is upset, I left my phone at home again
# ...           ...        ...                                            ...
# 39859  1753886681       love                              Happy Mothers Day
# 39898  1753902524       love                             happy mothers day!
# 39913  1753902827  happiness                            happy mother's day!
# 39915  1753903008       love                    happy mother's day everyone
# 39945  1753903727       love  Happy Mother's Day to all the moms out there!
#
# [173 rows x 3 columns]

# %%
df = df.drop_duplicates(subset= ["content"], keep = "first")

# %%
print(df.shape)
# Out:
# (39827, 3)

# %%
empty_tweets = (df["content"].fillna("").str.strip().eq("").sum())

print(f"Empty tweets:{empty_tweets}")
# Out:
# Empty tweets:0

# %%
df["char_count"] = (df["content"].fillna("").astype(str).apply(len))

# %%
df["word_count"] = (df["content"].fillna("").astype(str).apply(lambda x: len(x.split())))

# %%
df[['char_count','word_count']].describe()
# Out:
#          char_count    word_count
# count  39827.000000  39827.000000
# mean      73.530821     13.242599
# std       36.490448      6.962728
# min        1.000000      1.000000
# 25%       43.000000      7.000000
# 50%       69.000000     12.000000
# 75%      103.000000     19.000000
# max      167.000000     34.000000

# %%
plt.figure(figsize = (12,6))

sns.histplot(data= df, x= "word_count", bins = 50)
plt.title("Distribution of tweet word counts")
plt.xlabel("number of words")
plt.ylabel("number of tweets")

plt.show()

# %%
df.nsmallest(20, "word_count")[["sentiment","content","word_count"]]
# Out:
#      sentiment              content  word_count
# 98     neutral       PrinceCharming           1
# 340      empty                    0           1
# 659    neutral     @Joshuah_Pearson           1
# 664    neutral            @emlevins           1
# 1538   neutral             Hangover           1
# 1539   sadness           roughnight           1
# 1789   neutral  food...food...FOOD!           1
# 2206   neutral              nothing           1
# 2247   neutral         assignments!           1
# 2311   neutral             backache           1
# 2501   sadness             Headache           1
# 3181   neutral          @Clumsyflic           1
# 3883     worry             careless           1
# 4175  surprise              What!?!           1
# 4316   sadness              Work...           1
# 4378     anger           Confuzzled           1
# 4385     worry       doesntfeelwell           1
# 4865   neutral        @philleasfogg           1
# 4933   neutral           @WillKnott           1
# 5230     empty       @ShakeYourJunk           1

# %%
df[df["word_count"]< 3].head()
# Out:
#        tweet_id sentiment                                       content  \
# 16   1956971170      love                          @annarosekerr agreed
# 98   1956989561   neutral                                PrinceCharming
# 124  1956996673      hate  @britblackbird  youstinkatrespondingtotexts!
# 137  1957000077   neutral                                    miss 16'th
# 340  1957042734     empty                                             0
#
#      char_count  word_count
# 16           20           2
# 98           14           1
# 124          44           2
# 137          10           2
# 340           1           1

# %%
df.nlargest(20, "word_count")[["sentiment", "content", "word_count"]]
# Out:
#         sentiment  \
# 28293       worry
# 9818      neutral
# 17027       worry
# 1711         hate
# 2627      sadness
# 5459      sadness
# 7908         love
# 12868        love
# 13092     sadness
# 13435     neutral
# 13765       worry
# 14096     sadness
# 14146  enthusiasm
# 17825       worry
# 18692      relief
# 24149     neutral
# 27518     sadness
# 33287        love
# 33811   happiness
# 39601        love
#
#                                                                                                                                                     content  \
# 28293            hahas . dam tried . just nw got exam . don know how much i will get . . but i having fun today . with my pri sch friends  until 5plus . =D
# 9818              AK, flop comes 2K6 I bet 15 get raised to 25 I call, turn is A, we check, river rag, then I check and he bets 15, I raise 15 he calls, 22
# 17027             @oxEmalieexo: Lol it went okay! As far as I can tell . But then I had to do a test today for geo and I was all zoned out and got like 65%
# 1711           This is exactly y I hate driving thru dandy - sittin at lights next to a car of asians who r callin out to me &amp; 1 held up a knife  scum!
# 2627                   How I wish I get at least 2 days-off in a row. 1 day off is not enough to rest.  3 days on, 1 day off, 4 days on, 1 day off...Ugh!!!
# 5459             My car is in the car hospital for the nxt 7 days  I gotta go pick up a loaner car b4 6! Bein without wheels 4 7day will set me back heavy!
# 7908             Ahhh I am sooo happy Ashley Tisdale is in Germany but I am not in Oberhausen...  But i will show it in the TV at 8 o' clock yeah I love it
# 12868           @MadisonApril lol haha fresh to death lol ha ha I love and miss u 2 id almost given ï¿½ on u cuz u nvr respond 2me  but u did today! Luv u2
# 13092             Is Home Alone Yet Again; Mam And Dad Rather Go To The Club Than Stay In With Me Or Take Me Out; Yes I Think That Proves How Loved I Am  !
# 13435                     @chrisettefan yep. gotta go  man! i'll ttyl . . . eventually . . . sometime . . . in the future . . . hopefully . . . soon. ~ ~ ~
# 13765             ummmm i have no idea what im doing but my friend is pissed off at me now and i dont know why she hates me so much I NEED HELP BRITNEY plz
# 14096             @epiphanygirl man i missed it!! Ive been waitn all day 4 u 2 giv the tix away &amp; then whn im rappn up @ wrk u gav my tix away! Im sad!
# 14146             @Mileycyrus I can't Vote 4 u a the MTV movie awards. There is no vote button. Is it cause i live in sweden? I wanna vote 4 u 2  u rock xo
# 17825            Im not doing the hunt, i was in the middle of making it but all my work got erased  sry guys, now i look like a idiot for replying 2 all u
# 18692             i was so bored i decided to iron all my baju sklh. thn i realized i hate doing tht. so all i did was iron a sleeve HAHAHA. im off to schl
# 24149                    i got baby g wach its zi same as the 1 lady gaga wears in eh eh film clip but in pink!! I LOVE YOU KAY thanks a heap  i win olivia
# 27518                I got a full day of work today.  Can't wait in tell i get home for some beer and tv time  but i got to make the money to get the beers
# 33287            First Happy Mothers Day  Second what is it that makes us think the way we do? Why do we feel the way we feel? I dont know but i wish i did
# 33811              Hi-5 to ALL my friends and ummm thanks for the follow and enjoy the ride IF I make too many trips (I will) for u and u gotta go i get it
# 39601  my darling dd says &quot;my mum is my best friend&quot;... and she told me to tell you all she said that in here too  so I did! love ya moo (jd too)
#
#        word_count
# 28293          34
# 9818           33
# 17027          33
# 1711           32
# 2627           32
# 5459           32
# 7908           32
# 12868          32
# 13092          32
# 13435          32
# 13765          32
# 14096          32
# 14146          32
# 17825          32
# 18692          32
# 24149          32
# 27518          32
# 33287          32
# 33811          32
# 39601          32

# %%
plt.figure(figsize = (14,7))

sns.boxplot(data = df, x = "sentiment", y= "word_count")
plt.xticks(rotation = 45)
plt.title("tweet length by emotion")
plt.xlabel("Emotion")
plt.ylabel("Number of words")
plt.show()

# %%
def clean_tweet(text):

    text = str(text)

    text = text.lower()

    text = re.sub(r"http\S+|www\s+","<URL>",text)

    text = re.sub(r"@\w+", " <USER> ", text)

    text = re.sub(r"<.*?>", " ", text)

    text = re.sub(r"\s+", " ", text)

    text = text.strip()

    return text

# %%
df["clean_text"] = df["content"].apply(clean_tweet)

# %%
comparison = df[["content","clean_text"]].sample(10, random_state = 42)

# %%
comparison
# Out:
#                                                                                                                                           content  \
# 37761                                                                                                           the sun is shinning! im off out!!
# 1903                                   wow i must have been tired. i fell asleep @ exactly the start of the 10pm news &amp; now up as if its 8am.
# 16633                                                                                                                         @knobzie their loss
# 27370                                                                                                                 @Mickey_X sorry about that.
# 21139                                                                                                                      @tracymacy My pleasure
# 34688                                                                       Exhausted to the tee.. So i'm knocking out! Nighty night tweety birds
# 6250          @PochaccoYoly well, I took it in early '00, graduated in '01. we were the final stage guinea pigs  it seriously is a waste of time.
# 33181                                                           X-men movie was pretty good. Kinda predictable @ points but good action sequences
# 27193                                                                                                                     Less rain more sunshine
# 24904  Jamie @ Sean Cody, up for some angry sex?: Jamie @ Sean Cody, I wouldn't piss this one off  Hey there Guys, Do.. http://tinyurl.com/ddyyd6
#
#                                                                                                                  clean_text
# 37761                                                                                     the sun is shinning! im off out!!
# 1903             wow i must have been tired. i fell asleep @ exactly the start of the 10pm news &amp; now up as if its 8am.
# 16633                                                                                                            their loss
# 27370                                                                                                     sorry about that.
# 21139                                                                                                           my pleasure
# 34688                                                 exhausted to the tee.. so i'm knocking out! nighty night tweety birds
# 6250   well, i took it in early '00, graduated in '01. we were the final stage guinea pigs it seriously is a waste of time.
# 33181                                     x-men movie was pretty good. kinda predictable @ points but good action sequences
# 27193                                                                                               less rain more sunshine
# 24904       jamie @ sean cody, up for some angry sex?: jamie @ sean cody, i wouldn't piss this one off hey there guys, do..

# %%
all_text = " ".join(df["clean_text"])

words = all_text.split()

word_counts = Counter(words)

print(word_counts.most_common(30))
# Out:
# [('i', 18865), ('to', 14232), ('the', 12823), ('a', 9691), ('my', 7939), ('and', 7237), ('you', 6086), ('is', 5581), ('in', 5248), ('for', 5235), ('it', 4804), ('of', 4473), ('on', 4001), ('have', 3713), ('so', 3537), ('that', 3333), ('me', 3270), ('but', 3192), ('just', 3107), ("i'm", 3102), ('with', 2912), ('be', 2837), ('at', 2673), ('was', 2601), ('not', 2500), ('day', 2137), ('this', 2130), ('all', 2077), ('get', 1985), ('good', 1937)]

# %%
df["mentions"] = (df["content"].astype(str).str.count(r"@\w+"))
df["urls"] = (df["content"].astype(str).str.count(r"http\S+|www\S+"))
df["hashtags"] = (df["content"].astype(str).str.count(r"#\w+"))
df["exclamation_marks"] = (df["content"].astype(str).str.count(r"!"))
df["question_marks"] = (df["content"].astype(str).str.count(r"\?"))

# %%
df[["mentions", "urls", "hashtags","exclamation_marks","question_marks"]].describe()
# Out:
#            mentions          urls      hashtags  exclamation_marks  \
# count  39827.000000  39827.000000  39827.000000       39827.000000
# mean       0.501946      0.051322      0.023100           0.550506
# std        0.570553      0.226052      0.183617           1.345531
# min        0.000000      0.000000      0.000000           0.000000
# 25%        0.000000      0.000000      0.000000           0.000000
# 50%        0.000000      0.000000      0.000000           0.000000
# 75%        1.000000      0.000000      0.000000           1.000000
# max       10.000000      4.000000      9.000000          76.000000
#
#        question_marks
# count    39827.000000
# mean         0.168855
# std          1.224237
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max         98.000000

# %%
#prepare the target variables
#using the lable encoder
label_encoder = LabelEncoder()
df["label"] = label_encoder.fit_transform(df["sentiment"])

# %%
#View the mapping
for number, emotion in enumerate(label_encoder.classes_):
    print(number, "=", emotion)
# Out:
# 0 = anger
# 1 = boredom
# 2 = empty
# 3 = enthusiasm
# 4 = fun
# 5 = happiness
# 6 = hate
# 7 = love
# 8 = neutral
# 9 = relief
# 10 = sadness
# 11 = surprise
# 12 = worry

# %%
# sepreate data into its idnependednt and depenedet variable which will be the sentiment
# selecting x and y 
x = df["clean_text"]
y = df["label"]

# %%
#split dataset into 3 parts, training, validation and test part
x_train,x_test,y_train, y_test = train_test_split(x,y,test_size=0.3, random_state = 42, stratify = y)
# stratify ensures that that in both the training and test set there is the same proportion of the label
#validation set form the trainnig set 
x_train ,x_val, y_train, y_val = train_test_split(x_train,y_train,test_size = 0.2, random_state = 42, stratify = y_train)

# %%
# tokenise the tweets
# when we tokenise converts the words we have into numerical values because the model cant process the words 
# we dont use the enotre dictionry in order to select only the words that we need to use
max_words = 20000
tokenizer = Tokenizer(num_words = max_words,oov_token = "<OOV>")
tokenizer.fit_on_texts(x_train)

# %%
#how many unique words were labeled by the tokenizer

word_index = tokenizer.word_index
print(f"Vocab_size: {len(word_index)}")
# Out:
# Vocab_size: 22384

# %%
# convert the text to sequence 
# reconstructs the tweets using these ids 
x_train_seq = tokenizer.texts_to_sequences(x_train)
x_val_seq = tokenizer.texts_to_sequences(x_val)
x_test_seq = tokenizer.texts_to_sequences(x_test)

# %%
# choose a maximum sequence close to the max len(sentance)

# %%
sequence_lengths = [len(sequence) for sequence in x_train_seq]
print(pd.Series(sequence_lengths).describe())
# Out:
# count    22302.000000
# mean        12.828177
# std          7.068225
# min          0.000000
# 25%          7.000000
# 50%         12.000000
# 75%         18.000000
# max         36.000000
# dtype: float64

# %%
plt.figure(figsize = (10, 6))
sns.histplot(sequence_lengths, bins = 50)
plt.title("Distribution of token sequence")
plt.ylabel("Number of tweets")
plt.xlabel("Number of tokens")
plt.show()

# %%
# need to part the paragrapahs as it all has to all be the same size for the model to assert the data and actualy process the data for LSTM 
# Padding is going to cut off the tweets that are greater than the size set 
# truncating is going to cut tweets down to the right size ending up cuting of meaningful parts of the sentences
max_sequence = 50
x_train = pad_sequences(x_train_seq,maxlen = max_sequence, padding = "post", truncating = "post")
x_val = pad_sequences(x_val_seq,maxlen = max_sequence, padding = "post", truncating = "post") 
x_test = pad_sequences(x_test_seq,maxlen = max_sequence, padding = "post", truncating = "post") 

#post padding means after

# %%
# find the shape of this to check the shape to make sure they all the smae size
print(f"trining_shape {x_train.shape}")
print(f"x_val_shape {x_val.shape}")
print(f"x_test_shape {x_test.shape}")
# Out:
# trining_shape (22302, 50)
# x_val_shape (5576, 50)
# x_test_shape (11949, 50)

# %%
# build the LSTM
# explain each layer 
# tells us that the layers will be in a sequence or one after each other 
# multiple layers that perform different tasks
# first layer is the embedding
# converts what we generated from the tokeniser into a dense vector which carry more meaning 


model = Sequential()

# embedding layer with 2 params 
model.add(Embedding(input_dim = max_words, output_dim = 128)) # dimention is going to be 20000 to 128 


# LSTM LAYER 
# LSTM processes the sequence that comes from the embedding layer and learns the relationships between the wordds
model.add(LSTM(128))

# Dropout layer 
# Reduces overfit by disabling some neurons during the training process to reduce overfitting
model.add(Dropout(0.3)) # at each step it disables 30% of the neurons randomly

#Output layer 
# Dense Layer
# defines the type of activation function then it fits on the number of classes we have 
model.add(Dense(len(label_encoder.classes_), activation = "softmax")) #13 emotions # number of authors


# for multiclass classification problems 
# your dense layer accepts the number of classes in the label as output 
# for each of the classes softmax returns probability for each of the emotion classes. The total probablility sums up to 1
# the predicted class will be the class (emotions, author) with the highest probability 
# for the 13 emotions 
#example {dog, cat, lion}
# softmax generatws probabilities for each class{0.1,0.2,0.7} so the prediction will be the class with the highest probability  which is 0.7 lion
# Out:
# 2026-09-11 19:50:42.409862: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M4
# 2026-09-11 19:50:42.410030: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2026-09-11 19:50:42.410061: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.92 GB
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1789149042.410153 4110091 pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# I0000 00:00:1789149042.410256 4110091 pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model.compile(optimizer = "adam", loss = "sparse_categorical_crossentropy", metrics = ["accuracy"])
# for multiclass, we use the sparse_categorical_crossentropy loss function 
# optimiser = is used to improve the loss function in order to get the right weights 
# going to optimise the model to

# %%
# train
history = model.fit(x_train, y_train, validation_data = (x_val, y_val),
                    epochs = 20,
                    batch_size = 64,
                    verbose = 2)
# Out:
# Epoch 1/20
# 2026-09-11 19:50:48.656326: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 349/349 - 9s - 27ms/step - accuracy: 0.2124 - loss: 2.1749 - val_accuracy: 0.2118 - val_loss: 2.1509
# Epoch 2/20
# 349/349 - 6s - 16ms/step - accuracy: 0.2144 - loss: 2.1585 - val_accuracy: 0.2118 - val_loss: 2.1465
# Epoch 3/20
# 349/349 - 6s - 17ms/step - accuracy: 0.2162 - loss: 2.1543 - val_accuracy: 0.2331 - val_loss: 2.1448
# Epoch 4/20
# 349/349 - 6s - 17ms/step - accuracy: 0.2509 - loss: 2.1299 - val_accuracy: 0.2816 - val_loss: 2.0839
# Epoch 5/20
# 349/349 - 6s - 18ms/step - accuracy: 0.2967 - loss: 2.0164 - val_accuracy: 0.2886 - val_loss: 2.0156
# Epoch 6/20
# 349/349 - 6s - 18ms/step - accuracy: 0.3505 - loss: 1.8732 - val_accuracy: 0.3058 - val_loss: 2.0539
# Epoch 7/20
# 349/349 - 6s - 18ms/step - accuracy: 0.4102 - loss: 1.7326 - val_accuracy: 0.3077 - val_loss: 2.0911
# Epoch 8/20
# 349/349 - 6s - 18ms/step - accuracy: 0.4770 - loss: 1.5846 - val_accuracy: 0.2959 - val_loss: 2.1242
# Epoch 9/20
# 349/349 - 6s - 17ms/step - accuracy: 0.5437 - loss: 1.4179 - val_accuracy: 0.3043 - val_loss: 2.2593
# Epoch 10/20
# 349/349 - 6s - 17ms/step - accuracy: 0.6104 - loss: 1.2394 - val_accuracy: 0.2902 - val_loss: 2.3544
# Epoch 11/20
# 349/349 - 6s - 17ms/step - accuracy: 0.6705 - loss: 1.0754 - val_accuracy: 0.2952 - val_loss: 2.6205
# Epoch 12/20
# 349/349 - 6s - 17ms/step - accuracy: 0.7120 - loss: 0.9319 - val_accuracy: 0.2640 - val_loss: 2.6201
# Epoch 13/20
# 349/349 - 6s - 17ms/step - accuracy: 0.7529 - loss: 0.8171 - val_accuracy: 0.2676 - val_loss: 2.8502
# Epoch 14/20
# 349/349 - 6s - 17ms/step - accuracy: 0.7828 - loss: 0.7263 - val_accuracy: 0.2636 - val_loss: 2.9603
# Epoch 15/20
# 349/349 - 6s - 17ms/step - accuracy: 0.8017 - loss: 0.6596 - val_accuracy: 0.2635 - val_loss: 3.1050
# Epoch 16/20
# 349/349 - 6s - 17ms/step - accuracy: 0.8205 - loss: 0.5936 - val_accuracy: 0.2581 - val_loss: 3.1952
# Epoch 17/20
# 349/349 - 6s - 17ms/step - accuracy: 0.8332 - loss: 0.5485 - val_accuracy: 0.2525 - val_loss: 3.3628
# Epoch 18/20
# 349/349 - 6s - 17ms/step - accuracy: 0.8500 - loss: 0.4980 - val_accuracy: 0.2617 - val_loss: 3.5548
# Epoch 19/20
# 349/349 - 6s - 17ms/step - accuracy: 0.8626 - loss: 0.4577 - val_accuracy: 0.2374 - val_loss: 3.5483
# Epoch 20/20
# 349/349 - 6s - 17ms/step - accuracy: 0.8701 - loss: 0.4289 - val_accuracy: 0.2568 - val_loss: 3.9954

# %%
##You can consider higher values for the epoch 20, 30, 50 etc.
#The first two values are for training, while the last two values are for validation
#The measure the accuracy and loss for each set respectively
#As the number of epochs grow, the accuracy value should increase and the loss should decrease (expectation)

# if at the end of the training, the accuracy of the training set increases as the accuracy of the validation set increases it means the model is doing well 
# however if the accuracy of the traing continues to increase while accuracy of the validation set starts to decrease at some point that means that there is overfitting

# %%
# plot the graph of results 
plt.figure(figsize = (10, 6))
plt.plot(history.history["accuracy"], label = "Training Accuracy")
plt.plot(history.history["val_accuracy"], label = "validation accuracy")
plt.title("training vs validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
plt.figure(figsize = (10, 6))
plt.plot(history.history["loss"], label = "Training loss")
plt.plot(history.history["val_loss"], label = "validation loss")
plt.title("training vs validation loss")
plt.xlabel("Epochs")
plt.ylabel("loss")
plt.legend()
plt.show()
